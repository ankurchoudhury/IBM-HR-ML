# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'white')
sns.set(style = 'whitegrid', color_codes = True)

# %%
df = pd.read_csv(r'dataset.csv')
df.drop(['EmployeeCount', 'Over18', 'StandardHours', 'EmployeeNumber'],
        axis = 1,
        inplace = True)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df, x = 'Attrition')

# %% [markdown]
# The figure indicates that the dataset is highly imbalanced. The number of attrition cases is very small.<br>
# Though this is a true reflection of the real world, a balanced dataset is important to create a proper ML model.

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'StockOptionLevel')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'MonthlyIncome')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'JobLevel')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'JobSatisfaction')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'EnvironmentSatisfaction')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'Age')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'JobInvolvement')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'DistanceFromHome')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data = df, x = 'Attrition', y = 'NumCompaniesWorked')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df, x = 'BusinessTravel')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df, x = 'Department')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df, y = 'EducationField')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df, x = 'Gender')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df, y = 'JobRole')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df, x = 'MaritalStatus')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df, x = 'Education')

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df['Age'],kde = False, bins = 10)

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df['MonthlyIncome'],kde = False, bins = 10)
